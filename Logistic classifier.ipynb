# %%
import tensorflow as tf

# %%
x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

# %%
tf.model = tf.keras.Sequential() #빈모형? 생성
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2)) 
#layer.Dense->입출력을 모두 연결해줌. 
##units:출력뉴런 수
##input_dim:입력 뉴런 수

# %%
# use sigmoid activation for 0~1 problem
tf.model.add(tf.keras.layers.Activation('sigmoid')) #활성화함수 입력

# %%
''' 
better result with loss function == 'binary_crossentropy', try 'mse' for yourself
adding accuracy metric to get accuracy report during training
'''
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 3
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# ...
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = tf.model.fit(x_data, y_data, epochs=5000)

# Accuracy report
print("Accuracy: ", history.history['accuracy'][-1])
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5487 - accuracy: 0.5000
# Epoch 2/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4896 - accuracy: 0.5000
# Epoch 3/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4323 - accuracy: 0.5000
# Epoch 4/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3769 - accuracy: 0.5000
# Epoch 5/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3237 - accuracy: 0.5000
# Epoch 6/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2727 - accuracy: 0.5000
# Epoch 7/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2239 - accuracy: 0.5000
# Epoch 8/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1774 - accuracy: 0.5000
# Epoch 9/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1334 - accuracy: 0.5000
# Epoch 10/5000
# ...
